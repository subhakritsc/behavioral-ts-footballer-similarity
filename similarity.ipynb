# %%
import requests
import json

BASE = "https://raw.githubusercontent.com/statsbomb/open-data/master/data"

# 1) get competitions
comp = requests.get(f"{BASE}/competitions.json").json()

# find La Liga (Spain)
la_liga = [
    c for c in comp
    if c["competition_name"] == "Premier League"
]

print(la_liga)
# Out:
# [{'competition_id': 2, 'season_id': 27, 'country_name': 'England', 'competition_name': 'Premier League', 'competition_gender': 'male', 'competition_youth': False, 'competition_international': False, 'season_name': '2015/2016', 'match_updated': '2025-04-23T14:36:29.347042', 'match_updated_360': '2021-06-13T16:17:31.694', 'match_available_360': None, 'match_available': '2025-04-23T14:36:29.347042'}, {'competition_id': 2, 'season_id': 44, 'country_name': 'England', 'competition_name': 'Premier League', 'competition_gender': 'male', 'competition_youth': False, 'competition_international': False, 'season_name': '2003/2004', 'match_updated': '2025-06-24T13:53:07.585114', 'match_updated_360': '2021-06-13T16:17:31.694', 'match_available_360': None, 'match_available': '2025-06-24T13:53:07.585114'}]

# %%
competition_id = 2
season_id = 27

matches = requests.get(
    f"{BASE}/matches/{competition_id}/{season_id}.json"
).json()

print(len(matches))
print(matches[0])
# Out:
# 380
# {'match_id': 3754058, 'match_date': '2016-01-02', 'kick_off': '16:00:00.000', 'competition': {'competition_id': 2, 'country_name': 'England', 'competition_name': 'Premier League'}, 'season': {'season_id': 27, 'season_name': '2015/2016'}, 'home_team': {'home_team_id': 22, 'home_team_name': 'Leicester City', 'home_team_gender': 'male', 'home_team_group': None, 'country': {'id': 68, 'name': 'England'}, 'managers': [{'id': 60, 'name': 'Claudio Ranieri', 'nickname': None, 'dob': '1951-10-20', 'country': {'id': 112, 'name': 'Italy'}}]}, 'away_team': {'away_team_id': 28, 'away_team_name': 'AFC Bournemouth', 'away_team_gender': 'male', 'away_team_group': None, 'country': {'id': 68, 'name': 'England'}, 'managers': [{'id': 38, 'name': 'Eddie Howe', 'nickname': None, 'dob': '1977-11-29', 'country': {'id': 68, 'name': 'England'}}]}, 'home_score': 0, 'away_score': 0, 'match_status': 'available', 'match_status_360': 'processing', 'last_updated': '2021-10-29T23:44:19.940296', 'last_updated_360': '2021-06-12T16:17:31.694', 'metadata': {'data_version': '1.1.0', 'shot_fidelity_version': '2', 'xy_fidelity_version': '2'}, 'match_week': 20, 'competition_stage': {'id': 1, 'name': 'Regular Season'}, 'stadium': {'id': 20, 'name': 'King Power Stadium ', 'country': {'id': 68, 'name': 'England'}}, 'referee': {'id': 5, 'name': 'Andre Marriner', 'country': {'id': 68, 'name': 'England'}}}

# %%
match_ids = [m["match_id"] for m in matches]

with open("file_id.txt", "w") as f:
    for mid in match_ids:
        f.write(str(mid) + "\n")

print("Wrote all real match ids to file_id.txt")
# Out:
# Wrote all real match ids to file_id.txt

# %%
import os
import requests
from pathlib import Path

BASE_URL = "https://raw.githubusercontent.com/statsbomb/open-data/master/data"

def read_ids(path):
    with open(path) as f:
        return [line.strip() for line in f if line.strip()]

def download_file(url, save_path):
    r = requests.get(url, timeout=30)
    r.raise_for_status()
    with open(save_path, "wb") as f:
        f.write(r.content)

# %%
match_ids = read_ids("file_id.txt")

# สร้างโฟลเดอร์
Path("events").mkdir(exist_ok=True)
Path("lineups").mkdir(exist_ok=True)

for mid in match_ids:
    print(f"Downloading match {mid}...")

    event_url = f"{BASE_URL}/events/{mid}.json"
    lineup_url = f"{BASE_URL}/lineups/{mid}.json"

    download_file(event_url, f"events/{mid}.json")
    download_file(lineup_url, f"lineups/{mid}.json")

print("✅ Done. All files downloaded.")
# Out:
# Downloading match 3754058...
# Downloading match 3754245...
# Downloading match 3754136...
# Downloading match 3754037...
# Downloading match 3754039...
# Downloading match 3754041...
# Downloading match 3754042...
# Downloading match 3754043...
# Downloading match 3754045...
# Downloading match 3754048...
# Downloading match 3754049...
# Downloading match 3754050...
# Downloading match 3754052...
# Downloading match 3754053...
# Downloading match 3754055...
# Downloading match 3754226...
# Downloading match 3754014...
# Downloading match 3754091...
# Downloading match 3754135...
# Downloading match 3754293...
# Downloading match 3754339...
# Downloading match 3754146...
# Downloading match 3754347...
# Downloading match 3754255...
# Downloading match 3754278...
# Downloading match 3753979...
# Downloading match 3753972...
# Downloading match 3753978...
# Downloading match 3753974...
# Downloading match 3753993...
# Downloading match 3753983...
# Downloading match 3754015...
# Downloading match 3754038...
# Downloading match 3754001...
# Downloading match 3754007...
# Downloading match 3754008...
# Downloading match 3754029...
# Downloading match 3753995...
# Downloading match 3753999...
# Downloading match 3754017...
# Downloading match 3754006...
# Downloading match 3754023...
# Downloading match 3753984...
# Downloading match 3754011...
# Downloading match 3754010...
# Downloading match 3754028...
# Downloading match 3753996...
# Downloading match 3754025...
# Downloading match 3754068...
# Downloading match 3754056...
# Downloading match 3754040...
# Downloading match 3754074...
# Downloading match 3754076...
# Downloading match 3754067...
# Downloading match 3754079...
# Downloading match 3754090...
# Downloading match 3754083...
# Downloading match 3754077...
# Downloading match 3754060...
# Downloading match 3754073...
# Downloading match 3754085...
# Downloading match 3754047...
# Downloading match 3754051...
# Downloading match 3754093...
# Downloading match 3754046...
# Downloading match 3754072...
# Downloading match 3754082...
# Downloading match 3754106...
# Downloading match 3754099...
# Downloading match 3754098...
# Downloading match 3754057...
# Downloading match 3754112...
# Downloading match 3754117...
# Downloading match 3754104...
# Downloading match 3754054...
# Downloading match 3754113...
# Downloading match 3754107...
# Downloading match 3754105...
# Downloading match 3754097...
# Downloading match 3754102...
# Downloading match 3754115...
# Downloading match 3754148...
# Downloading match 3754169...
# Downloading match 3754174...
# Downloading match 3754185...
# Downloading match 3754162...
# Downloading match 3754096...
# Downloading match 3754171...
# Downloading match 3754119...
# Downloading match 3754126...
# Downloading match 3754133...
# Downloading match 3754167...
# Downloading match 3754145...
# Downloading match 3754153...
# Downloading match 3754143...
# Downloading match 3754186...
# Downloading match 3754130...
# Downloading match 3754188...
# Downloading match 3754178...
# Downloading match 3754157...
# Downloading match 3754166...
# Downloading match 3754211...
# Downloading match 3754150...
# Downloading match 3754160...
# Downloading match 3754218...
# Downloading match 3754217...
# Downloading match 3754205...
# Downloading match 3754221...
# Downloading match 3754198...
# Downloading match 3754193...
# Downloading match 3754222...
# Downloading match 3754213...
# Downloading match 3754212...
# Downloading match 3754223...
# Downloading match 3754197...
# Downloading match 3754208...
# Downloading match 3754204...
# Downloading match 3754194...
# Downloading match 3754219...
# Downloading match 3754254...
# Downloading match 3754230...
# Downloading match 3754285...
# Downloading match 3754233...
# Downloading match 3754270...
# Downloading match 3754237...
# Downloading match 3754257...
# Downloading match 3754266...
# Downloading match 3754256...
# Downloading match 3754288...
# Downloading match 3754238...
# Downloading match 3754269...
# Downloading match 3754234...
# Downloading match 3754246...
# Downloading match 3754296...
# Downloading match 3754273...
# Downloading match 3754263...
# Downloading match 3754268...
# Downloading match 3754286...
# Downloading match 3754291...
# Downloading match 3754283...
# Downloading match 3754235...
# Downloading match 3754279...
# Downloading match 3754276...
# Downloading match 3754287...
# Downloading match 3754259...
# Downloading match 3754335...
# Downloading match 3754298...
# Downloading match 3754315...
# Downloading match 3754330...
# Downloading match 3754337...
# Downloading match 3754297...
# Downloading match 3754301...
# Downloading match 3754323...
# Downloading match 3754304...
# Downloading match 3754311...
# Downloading match 3754328...
# Downloading match 3754309...
# Downloading match 3754325...
# Downloading match 3754329...
# Downloading match 3754302...
# Downloading match 3754013...
# Downloading match 3754044...
# Downloading match 3754351...
# Downloading match 3754343...
# Downloading match 3754109...
# Downloading match 3754182...
# Downloading match 3754240...
# Downloading match 3754336...
# Downloading match 3754247...
# Downloading match 3754156...
# Downloading match 3754265...
# Downloading match 3754000...
# Downloading match 3754003...
# Downloading match 3754344...
# Downloading match 3754131...
# Downloading match 3754300...
# Downloading match 3754312...
# Downloading match 3754138...
# Downloading match 3754203...
# Downloading match 3754190...
# Downloading match 3754066...
# Downloading match 3754034...
# Downloading match 3753985...
# Downloading match 3753987...
# Downloading match 3754189...
# Downloading match 3754129...
# Downloading match 3754180...
# Downloading match 3754059...
# Downloading match 3754064...
# Downloading match 3754065...
# Downloading match 3754173...
# Downloading match 3754175...
# Downloading match 3753973...
# Downloading match 3753975...
# Downloading match 3753976...
# Downloading match 3753977...
# Downloading match 3753980...
# Downloading match 3753981...
# Downloading match 3753982...
# Downloading match 3753986...
# Downloading match 3753988...
# Downloading match 3753989...
# Downloading match 3753990...
# Downloading match 3753991...
# Downloading match 3753992...
# Downloading match 3753994...
# Downloading match 3753997...
# Downloading match 3753998...
# Downloading match 3754002...
# Downloading match 3754004...
# Downloading match 3754005...
# Downloading match 3754009...
# Downloading match 3754012...
# Downloading match 3754016...
# Downloading match 3754018...
# Downloading match 3754019...
# Downloading match 3754021...
# Downloading match 3754022...
# Downloading match 3754024...
# Downloading match 3754026...
# Downloading match 3754027...
# Downloading match 3754030...
# Downloading match 3754031...
# Downloading match 3754032...
# Downloading match 3754033...
# Downloading match 3754035...
# Downloading match 3754036...
# Downloading match 3754061...
# Downloading match 3754062...
# Downloading match 3754063...
# Downloading match 3754069...
# Downloading match 3754070...
# Downloading match 3754071...
# Downloading match 3754075...
# Downloading match 3754080...
# Downloading match 3754081...
# Downloading match 3754084...
# Downloading match 3754086...
# Downloading match 3754087...
# Downloading match 3754088...
# Downloading match 3754089...
# Downloading match 3754092...
# Downloading match 3754094...
# Downloading match 3754095...
# Downloading match 3754100...
# Downloading match 3754101...
# Downloading match 3754103...
# Downloading match 3754108...
# Downloading match 3754110...
# Downloading match 3754111...
# Downloading match 3754114...
# Downloading match 3754116...
# Downloading match 3754118...
# Downloading match 3754120...
# Downloading match 3754121...
# Downloading match 3754122...
# Downloading match 3754123...
# Downloading match 3754124...
# Downloading match 3754125...
# Downloading match 3754127...
# Downloading match 3754132...
# Downloading match 3754134...
# Downloading match 3754137...
# Downloading match 3754139...
# Downloading match 3754140...
# Downloading match 3754142...
# Downloading match 3754144...
# Downloading match 3754147...
# Downloading match 3754149...
# Downloading match 3754151...
# Downloading match 3754152...
# Downloading match 3754154...
# Downloading match 3754155...
# Downloading match 3754158...
# Downloading match 3754159...
# Downloading match 3754161...
# Downloading match 3754163...
# Downloading match 3754164...
# Downloading match 3754165...
# Downloading match 3754168...
# Downloading match 3754170...
# Downloading match 3754172...
# Downloading match 3754176...
# Downloading match 3754177...
# Downloading match 3754179...
# Downloading match 3754181...
# Downloading match 3754183...
# Downloading match 3754184...
# Downloading match 3754187...
# Downloading match 3754191...
# Downloading match 3754192...
# Downloading match 3754195...
# Downloading match 3754196...
# Downloading match 3754199...
# Downloading match 3754200...
# Downloading match 3754201...
# Downloading match 3754202...
# Downloading match 3754206...
# Downloading match 3754207...
# Downloading match 3754209...
# Downloading match 3754210...
# Downloading match 3754214...
# Downloading match 3754215...
# Downloading match 3754216...
# Downloading match 3754220...
# Downloading match 3754224...
# Downloading match 3754225...
# Downloading match 3754227...
# Downloading match 3754228...
# Downloading match 3754229...
# Downloading match 3754231...
# Downloading match 3754232...
# Downloading match 3754236...
# Downloading match 3754239...
# Downloading match 3754241...
# Downloading match 3754242...
# Downloading match 3754243...
# Downloading match 3754244...
# Downloading match 3754249...
# Downloading match 3754250...
# Downloading match 3754251...
# Downloading match 3754252...
# Downloading match 3754253...
# Downloading match 3754260...
# Downloading match 3754261...
# Downloading match 3754262...
# Downloading match 3754264...
# Downloading match 3754295...
# Downloading match 3754271...
# Downloading match 3754272...
# Downloading match 3754274...
# Downloading match 3754275...
# Downloading match 3754277...
# Downloading match 3754280...
# Downloading match 3754281...
# Downloading match 3754282...
# Downloading match 3754284...
# Downloading match 3754289...
# Downloading match 3754290...
# Downloading match 3754292...
# Downloading match 3754294...
# Downloading match 3754248...
# Downloading match 3754299...
# Downloading match 3754303...
# Downloading match 3754305...
# Downloading match 3754306...
# Downloading match 3754307...
# Downloading match 3754308...
# Downloading match 3754310...
# Downloading match 3754313...
# Downloading match 3754314...
# Downloading match 3754316...
# Downloading match 3754317...
# Downloading match 3754318...
# Downloading match 3754319...
# Downloading match 3754320...
# Downloading match 3754321...
# Downloading match 3754322...
# Downloading match 3754324...
# Downloading match 3754326...
# Downloading match 3754327...
# Downloading match 3754331...
# Downloading match 3754332...
# Downloading match 3754333...
# Downloading match 3754334...
# Downloading match 3754338...
# Downloading match 3754340...
# Downloading match 3754341...
# Downloading match 3754342...
# Downloading match 3754345...
# Downloading match 3754346...
# Downloading match 3754348...
# Downloading match 3754349...
# Downloading match 3754350...
# Downloading match 3754258...
# Downloading match 3754020...
# Downloading match 3754267...
# Downloading match 3754141...
# Downloading match 3754128...
# Downloading match 3754078...
# ✅ Done. All files downloaded.

# %%
# !pip install pandas numpy tqdm tslearn matplotlib streamlit

# %%
import json
import pandas as pd
from pathlib import Path

def load_events(events_path):
    rows = []

    for file in Path(events_path).glob("*.json"):
        with open(file) as f:
            data = json.load(f)

        for e in data:
            if 'player' not in e:
                continue

            rows.append({
                "match_id": file.stem,
                "minute": e.get("minute", 0),
                "player": e["player"]["name"],
                "team": e["team"]["name"],
                "type": e["type"]["name"],
                "x": e.get("location", [None, None])[0],
                "y": e.get("location", [None, None])[1],
            })

    return pd.DataFrame(rows)

# %%
import pandas as pd
import numpy as np

def build_player_ts(df):
    df["minute_bin"] = df["minute"].clip(0, 89)

    def agg_minute(x):
        return pd.Series({
            "touches": len(x),
            "passes": (x["type"] == "Pass").sum(),
            "carries": (x["type"] == "Carry").sum(),
            "defensive_actions": x["type"].isin(
                ["Duel", "Ball Recovery", "Interception", "Clearance"]
            ).sum(),
            "avg_x": x["x"].mean(),
            "avg_y": x["y"].mean(),
        })

    ts = (
        df.groupby(["player", "match_id", "minute_bin"])
        .apply(agg_minute)
        .reset_index()
    )

    # Ensure every player has 90 rows (fill missing minutes)
    full = []
    for (player, match), g in ts.groupby(["player", "match_id"]):
        g = g.set_index("minute_bin").reindex(range(90), fill_value=0)
        g["player"] = player
        g["match_id"] = match
        g["minute_bin"] = g.index
        full.append(g.reset_index(drop=True))

    return pd.concat(full, ignore_index=True)

# %%
import numpy as np

FEATURES = [
    "touches",
    "passes",
    "carries",
    "defensive_actions",
    "avg_x",
    "avg_y",
]

def to_dtw_format(ts_df):
    players = {}

    for player, g in ts_df.groupby("player"):
        g = (
            g.groupby("minute_bin")[FEATURES]
            .mean()
            .fillna(0)
        )

        players[player] = g.values  # 90 x F

    return players

# %%
from tslearn.metrics import dtw
from tqdm import tqdm

def compute_similarity(players_ts, target_key):
    target_ts = players_ts[target_key]
    scores = []

    for key, ts in tqdm(players_ts.items()):
        if key == target_key:
            continue

        dist = dtw(target_ts, ts)
        scores.append((key, dist))

    scores.sort(key=lambda x: x[1])
    return scores

# %%
import json
import os
import pandas as pd

def load_positions(lineup_path="lineups"):
    pos = {}

    for file in os.listdir(lineup_path):
        with open(os.path.join(lineup_path, file)) as f:
            data = json.load(f)

        for team in data:
            for p in team["lineup"]:
                name = p["player_name"]

                # skip if already found
                if name in pos:
                    continue

                positions = p.get("positions", [])

                if len(positions) > 0:
                    position = positions[0]["position"]
                    pos[name] = position

    return pd.DataFrame([
        {"player": k, "position": v}
        for k, v in pos.items()
    ])

def map_position(pos):
    pos = pos.lower()

    if "goalkeeper" in pos:
        return "GK"

    if "center back" in pos or pos == "center back":
        return "CB"

    if "left back" in pos:
        return "LB"

    if "right back" in pos:
        return "RB"

    if "wing back" in pos:
        return "WB"

    if "defensive midfield" in pos:
        return "CDM"

    if "center midfield" in pos:
        return "CM"

    if "attacking midfield" in pos:
        return "CAM"

    if "left midfield" in pos:
        return "LM"

    if "right midfield" in pos:
        return "RM"

    if "left wing" in pos:
        return "LW"

    if "right wing" in pos:
        return "RW"

    if "center forward" in pos:
        return "CF"

    return "UNK"  # เผื่อกรณีแปลก ๆ

df = load_positions()
df["position"] = df["position"].apply(map_position)

df.to_csv("positions.csv", index=False)
print("positions.csv created:", df.shape)
# Out:
# positions.csv created: (550, 2)

# %%
import pandas as pd
from tslearn.metrics import dtw
from tqdm import tqdm
from itertools import combinations
from collections import defaultdict

FEATURES = [
    "touches",
    "passes",
    "carries",
    "defensive_actions",
    "avg_x",
    "avg_y"
]

ts_df = pd.read_csv("player_timeseries.csv")
players = ts_df["player"].unique()


def prepare_ts(df, player):
    p = df[df.player == player]

    full = pd.DataFrame({"minute_bin": range(1, 91)})
    p = full.merge(p, on="minute_bin", how="left")
    p[FEATURES] = p[FEATURES].fillna(0)

    return p[FEATURES].values


# ===== Cache TS =====
player_ts = {}
for p in players:
    player_ts[p] = prepare_ts(ts_df, p)


# ===== Compute DTW only once per pair =====
dist_map = defaultdict(dict)

pairs = list(combinations(players, 2))

for p1, p2 in tqdm(pairs):
    d = dtw(player_ts[p1], player_ts[p2])
    dist_map[p1][p2] = d
    dist_map[p2][p1] = d  # reuse result


# ===== Build Top3 =====
rows = []

for p in players:
    scores = list(dist_map[p].items())
    scores.sort(key=lambda x: x[1])

    for sp, _ in scores[:3]:
        rows.append({
            "player": p,
            "similar_player": sp
        })

pd.DataFrame(rows).to_csv("top3_similarity.csv", index=False)
# Out:
# 100%|██████████| 150426/150426 [32:00<00:00, 78.33it/s]
